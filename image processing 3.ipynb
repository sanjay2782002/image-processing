# %%
import os
import warnings
import pandas as pd
import numpy as np
warnings.simplefilter('ignore')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
MADS_MIKKELSEN=os.listdir("C:/Users/lathi/OneDrive/Desktop/dataset/mads/")

# %%
KEANU=os.listdir("C:/Users/lathi/dataset/keanu reeves/")

# %%
DICAPRIO=os.listdir("C:/Users/lathi/dataset/leonardo dicaprio/")

# %%
limit=20
MADS_IMAGES=[None]*limit
j=0
for i in MADS_MIKKELSEN:
    if(j<limit):
        MADS_IMAGES[j]=imread("C:/Users/lathi/OneDrive/Desktop/dataset/mads/"+i)
        j+=1
    else:
        break

# %%
limit=20
KEANU_IMAGES=[None]*limit
j=0
for i in KEANU :
    if(j<limit):
        KEANU_IMAGES[j]=imread("C:/Users/lathi/dataset/keanu reeves/"+i)
        j+=1
    else:
        break

# %%
limit=20
DICAPRIO_IMAGES=[None]*limit
j=0
for i in DICAPRIO  :
    if(j<limit):
        DICAPRIO_IMAGES[j]=imread("C:/Users/lathi/dataset/leonardo dicaprio/"+i)
        j+=1
    else:
        break

# %%
imshow(MADS_IMAGES[5])

# %%
imshow(DICAPRIO_IMAGES[5])

# %%
imshow(KEANU_IMAGES[5])

# %%
limit=10
MADS_gray=[None]*limit
j=0
for i in MADS_MIKKELSEN:
    if(j<limit):
        MADS_gray[j]=rgb2gray(MADS_IMAGES[j][:,:,:3])
        j+=1
    else:
        break

# %%
imshow(MADS_gray[5])

# %%
limit=20
KEANU_gray=[None]*limit
j=0
for i in KEANU :
    if(j<limit):
        KEANU_gray[j]=rgb2gray(KEANU_IMAGES[j][:,:,:3])
        j+=1
    else:
        break

# %%
imshow(KEANU_gray[5])

# %%
limit=20
DICAPRIO_gray=[None]*limit
j=0
for i in DICAPRIO  :
    if(j<limit):
        DICAPRIO_gray[j]=rgb2gray(DICAPRIO_IMAGES[j][:,:,:3])
        j+=1
    else:
        break

# %%
imshow(DICAPRIO_gray[5])

# %%
for j in range(10):
    r1=MADS_gray[j]
    MADS_gray[j]=resize(r1,(512,512))

# %%
for j in range(20):
    r2=KEANU_gray[j]
    KEANU_gray[j]=resize(r2,(512,512))

# %%
for j in range(20):
    r3=DICAPRIO_gray[j]
    DICAPRIO_gray[j]=resize(r3,(512,512))

# %%
MADS_gray[5].shape
# Out:
# (512, 512)

# %%
KEANU_gray[5].shape
# Out:
# (512, 512)

# %%
DICAPRIO_gray[5].shape
# Out:
# (512, 512)

# %%
imshow(MADS_gray[5])

# %%
imshow(KEANU_gray[5])

# %%
imshow(DICAPRIO_gray[5])

# %%
len_of_images_MADS=len(MADS_gray)

# %%
len_of_images_MADS
# Out:
# 10

# %%
image_size_MADS=MADS_gray[5].shape

# %%
image_size_MADS
# Out:
# (512, 512)

# %%
flatten_size_MADS=image_size_MADS[0]*image_size_MADS[1]

# %%
flatten_size_MADS
# Out:
# 262144

# %%
for i in range(len_of_images_MADS):
    MADS_gray[i]=np.ndarray.flatten(MADS_gray[i]).reshape(flatten_size_MADS,1)

# %%
MADS_gray=np.dstack(MADS_gray)
MADS_gray.shape
# Out:
# (262144, 1, 10)

# %%
MADS_gray=np.rollaxis(MADS_gray,axis=2,start=0)

# %%
MADS_gray.shape
# Out:
# (10, 262144, 1)

# %%
MADS_gray=MADS_gray.reshape(len_of_images_MADS,flatten_size_MADS)

# %%
MADS_gray.shape
# Out:
# (10, 262144)

# %%
MADS_data=pd.DataFrame(MADS_gray)

# %%
MADS_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.643137  0.643137  0.643137  0.643137  0.643137  0.643137  0.643137
# 1  0.283098  0.282483  0.255943  0.221976  0.181549  0.140360  0.098565
# 2  0.819103  0.819103  0.819103  0.819103  0.819103  0.819103  0.819103
# 3  0.231373  0.231373  0.231373  0.231223  0.229500  0.227777  0.224655
# 4  0.424302  0.428376  0.444139  0.461273  0.478134  0.492385  0.504620
# 5  0.628195  0.628195  0.628195  0.628195  0.628195  0.628195  0.628195
# 6  0.469245  0.469152  0.468475  0.467266  0.465836  0.465043  0.464366
# 7  0.139085  0.139085  0.139085  0.139085  0.139656  0.141962  0.143007
# 8  0.042740  0.042804  0.044185  0.045922  0.047929  0.050320  0.052952
# 9  0.095363  0.090506  0.096594  0.102682  0.110283  0.121357  0.132431
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.643137  0.643137  0.643137  ...  0.134653  0.134653  0.134653  0.134653
# ...

# %%
MADS_data["label"]="MADS"

# %%
MADS_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.643137  0.643137  0.643137  0.643137  0.643137  0.643137  0.643137
# 1  0.283098  0.282483  0.255943  0.221976  0.181549  0.140360  0.098565
# 2  0.819103  0.819103  0.819103  0.819103  0.819103  0.819103  0.819103
# 3  0.231373  0.231373  0.231373  0.231223  0.229500  0.227777  0.224655
# 4  0.424302  0.428376  0.444139  0.461273  0.478134  0.492385  0.504620
# 5  0.628195  0.628195  0.628195  0.628195  0.628195  0.628195  0.628195
# 6  0.469245  0.469152  0.468475  0.467266  0.465836  0.465043  0.464366
# 7  0.139085  0.139085  0.139085  0.139085  0.139656  0.141962  0.143007
# 8  0.042740  0.042804  0.044185  0.045922  0.047929  0.050320  0.052952
# 9  0.095363  0.090506  0.096594  0.102682  0.110283  0.121357  0.132431
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.643137  0.643137  0.643137  ...  0.134653  0.134653  0.134653  0.134653
# ...

# %%
len_of_images_KEANU=len(KEANU_gray)

# %%
len_of_images_KEANU
# Out:
# 20

# %%
image_size_KEANU=KEANU_gray[5].shape

# %%
image_size_KEANU
# Out:
# (512, 512)

# %%
flatten_size_KEANU=image_size_KEANU[0]*image_size_KEANU[1]

# %%
flatten_size_KEANU
# Out:
# 262144

# %%
for i in range(len_of_images_KEANU):
    KEANU_gray[i]=np.ndarray.flatten(KEANU_gray[i]).reshape(flatten_size_KEANU,1)

# %%
KEANU_gray=np.dstack(KEANU_gray)
KEANU_gray.shape
# Out:
# (262144, 1, 20)

# %%
KEANU_gray=np.rollaxis(KEANU_gray,axis=2,start=0)

# %%
KEANU_gray.shape
# Out:
# (20, 262144, 1)

# %%
KEANU_gray=KEANU_gray.reshape(len_of_images_KEANU,flatten_size_KEANU)

# %%
KEANU_gray.shape
# Out:
# (20, 262144)

# %%
KEANU_data=pd.DataFrame(KEANU_gray)

# %%
KEANU_data
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.608205  0.610559  0.612053  0.616518  0.621147  0.622859  0.624859
# 1   0.809174  0.809975  0.810018  0.810294  0.811658  0.812054  0.815428
# 2   0.491180  0.491180  0.491180  0.491180  0.491180  0.491180  0.491180
# 3   0.275982  0.281546  0.285480  0.285174  0.284308  0.284302  0.284301
# 4   0.023529  0.023529  0.023529  0.023529  0.023529  0.023529  0.023989
# 5   0.441643  0.438301  0.433804  0.429923  0.425967  0.429874  0.429881
# 6   0.838330  0.838330  0.838330  0.838330  0.838330  0.838330  0.838330
# 7   0.552549  0.552549  0.552549  0.552549  0.552549  0.552549  0.552549
# 8   0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 9   0.003333  0.003333  0.003333  0.003333  0.003333  0.003333  0.003333
# 10  0.877535  0.851821  0.793999  0.715684  0.610039  0.465794  0.389480
# 11  0.287356  0.288013  0.288103  0.287367  0.287276  0.284564  0.284327
# ...

# %%
KEANU_data["label"]="KEANU"

# %%
KEANU_data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.608205  0.610559  0.612053  0.616518  0.621147  0.622859  0.624859
# 1   0.809174  0.809975  0.810018  0.810294  0.811658  0.812054  0.815428
# 2   0.491180  0.491180  0.491180  0.491180  0.491180  0.491180  0.491180
# 3   0.275982  0.281546  0.285480  0.285174  0.284308  0.284302  0.284301
# 4   0.023529  0.023529  0.023529  0.023529  0.023529  0.023529  0.023989
# 5   0.441643  0.438301  0.433804  0.429923  0.425967  0.429874  0.429881
# 6   0.838330  0.838330  0.838330  0.838330  0.838330  0.838330  0.838330
# 7   0.552549  0.552549  0.552549  0.552549  0.552549  0.552549  0.552549
# 8   0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 9   0.003333  0.003333  0.003333  0.003333  0.003333  0.003333  0.003333
# 10  0.877535  0.851821  0.793999  0.715684  0.610039  0.465794  0.389480
# 11  0.287356  0.288013  0.288103  0.287367  0.287276  0.284564  0.284327
# ...

# %%
len_of_images_DICAPRIO=len(DICAPRIO_gray)

# %%
len_of_images_DICAPRIO
# Out:
# 20

# %%
image_size_DICAPRIO=DICAPRIO_gray[5].shape

# %%
image_size_DICAPRIO
# Out:
# (512, 512)

# %%
flatten_size_DICAPRIO=image_size_DICAPRIO[0]*image_size_DICAPRIO[1]

# %%
flatten_size_DICAPRIO
# Out:
# 262144

# %%
for i in range(len_of_images_DICAPRIO):
    DICAPRIO_gray[i]=np.ndarray.flatten(DICAPRIO_gray[i]).reshape(flatten_size_DICAPRIO,1)

# %%
DICAPRIO_gray=np.dstack(DICAPRIO_gray)
DICAPRIO_gray.shape
# Out:
# (262144, 1, 20)

# %%
DICAPRIO_gray=np.rollaxis(DICAPRIO_gray,axis=2,start=0)

# %%
DICAPRIO_gray.shape
# Out:
# (20, 262144, 1)

# %%
DICAPRIO_gray=DICAPRIO_gray.reshape(len_of_images_DICAPRIO,flatten_size_DICAPRIO)

# %%
DICAPRIO_gray.shape
# Out:
# (20, 262144)

# %%
DICAPRIO_data=pd.DataFrame(DICAPRIO_gray)

# %%
DICAPRIO_data
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.686338  0.693988  0.685416  0.681476  0.686938  0.688937  0.690842
# 1   0.213941  0.212796  0.218391  0.224884  0.230885  0.235381  0.235235
# 2   0.967861  0.967651  0.966959  0.966354  0.965877  0.967576  0.966238
# 3   0.858893  0.859512  0.862803  0.864370  0.869836  0.878316  0.877549
# 4   0.040143  0.037432  0.036586  0.040508  0.038942  0.036464  0.037743
# 5   0.073742  0.067381  0.066826  0.058852  0.058603  0.042066  0.046717
# 6   0.063166  0.065953  0.062921  0.062492  0.073455  0.074499  0.076438
# 7   0.188603  0.163704  0.192589  0.203723  0.192765  0.184314  0.191926
# 8   0.159143  0.115738  0.080217  0.066400  0.057193  0.047437  0.046326
# 9   0.359639  0.360484  0.356355  0.363803  0.360904  0.353488  0.355822
# 10  0.044834  0.045206  0.044840  0.044488  0.043822  0.043251  0.043950
# 11  0.616467  0.606593  0.594338  0.584062  0.569585  0.566837  0.563021
# ...

# %%
DICAPRIO_data["label"]="DICAPRIO"

# %%
DICAPRIO_data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.686338  0.693988  0.685416  0.681476  0.686938  0.688937  0.690842
# 1   0.213941  0.212796  0.218391  0.224884  0.230885  0.235381  0.235235
# 2   0.967861  0.967651  0.966959  0.966354  0.965877  0.967576  0.966238
# 3   0.858893  0.859512  0.862803  0.864370  0.869836  0.878316  0.877549
# 4   0.040143  0.037432  0.036586  0.040508  0.038942  0.036464  0.037743
# 5   0.073742  0.067381  0.066826  0.058852  0.058603  0.042066  0.046717
# 6   0.063166  0.065953  0.062921  0.062492  0.073455  0.074499  0.076438
# 7   0.188603  0.163704  0.192589  0.203723  0.192765  0.184314  0.191926
# 8   0.159143  0.115738  0.080217  0.066400  0.057193  0.047437  0.046326
# 9   0.359639  0.360484  0.356355  0.363803  0.360904  0.353488  0.355822
# 10  0.044834  0.045206  0.044840  0.044488  0.043822  0.043251  0.043950
# 11  0.616467  0.606593  0.594338  0.584062  0.569585  0.566837  0.563021
# ...

# %%
actor_1=pd.concat([MADS_data,KEANU_data])

# %%
actor=pd.concat([actor_1,DICAPRIO_data])

# %%
actor
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.643137  0.643137  0.643137  0.643137  0.643137  0.643137  0.643137
# 1   0.283098  0.282483  0.255943  0.221976  0.181549  0.140360  0.098565
# 2   0.819103  0.819103  0.819103  0.819103  0.819103  0.819103  0.819103
# 3   0.231373  0.231373  0.231373  0.231223  0.229500  0.227777  0.224655
# 4   0.424302  0.428376  0.444139  0.461273  0.478134  0.492385  0.504620
# 5   0.628195  0.628195  0.628195  0.628195  0.628195  0.628195  0.628195
# 6   0.469245  0.469152  0.468475  0.467266  0.465836  0.465043  0.464366
# 7   0.139085  0.139085  0.139085  0.139085  0.139656  0.141962  0.143007
# 8   0.042740  0.042804  0.044185  0.045922  0.047929  0.050320  0.052952
# 9   0.095363  0.090506  0.096594  0.102682  0.110283  0.121357  0.132431
# 0   0.608205  0.610559  0.612053  0.616518  0.621147  0.622859  0.624859
# 1   0.809174  0.809975  0.810018  0.810294  0.811658  0.812054  0.815428
# ...

# %%
from sklearn.utils import shuffle

# %%
hollywood_indexed=shuffle(actor).reset_index()

# %%
hollywood_indexed
# Out:
#     index         0         1         2         3         4         5  \
# 0       7  0.139085  0.139085  0.139085  0.139085  0.139656  0.141962
# 1       2  0.491180  0.491180  0.491180  0.491180  0.491180  0.491180
# 2       8  0.159143  0.115738  0.080217  0.066400  0.057193  0.047437
# 3       9  0.003333  0.003333  0.003333  0.003333  0.003333  0.003333
# 4       5  0.441643  0.438301  0.433804  0.429923  0.425967  0.429874
# 5      12  0.903384  0.899718  0.897871  0.891881  0.894977  0.890113
# 6      10  0.877535  0.851821  0.793999  0.715684  0.610039  0.465794
# 7      17  0.482334  0.479531  0.482738  0.479672  0.479785  0.474832
# 8      14  0.230148  0.227471  0.233554  0.237870  0.229746  0.227551
# 9      19  0.000666  0.004447  0.007971  0.007853  0.007836  0.007844
# 10     12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11     11  0.616467  0.606593  0.594338  0.584062  0.569585  0.566837
# ...

# %%
hollywood_actors=hollywood_indexed.drop(['index'],axis=1)

# %%
hollywood_actors
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.139085  0.139085  0.139085  0.139085  0.139656  0.141962  0.143007
# 1   0.491180  0.491180  0.491180  0.491180  0.491180  0.491180  0.491180
# 2   0.159143  0.115738  0.080217  0.066400  0.057193  0.047437  0.046326
# 3   0.003333  0.003333  0.003333  0.003333  0.003333  0.003333  0.003333
# 4   0.441643  0.438301  0.433804  0.429923  0.425967  0.429874  0.429881
# 5   0.903384  0.899718  0.897871  0.891881  0.894977  0.890113  0.891273
# 6   0.877535  0.851821  0.793999  0.715684  0.610039  0.465794  0.389480
# 7   0.482334  0.479531  0.482738  0.479672  0.479785  0.474832  0.473481
# 8   0.230148  0.227471  0.233554  0.237870  0.229746  0.227551  0.243288
# 9   0.000666  0.004447  0.007971  0.007853  0.007836  0.007844  0.007855
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.616467  0.606593  0.594338  0.584062  0.569585  0.566837  0.563021
# ...

# %%
x=hollywood_actors.values[:,:-1]

# %%
y=hollywood_actors.values[:,-1]

# %%
x
# Out:
# array([[0.13908549019607847, 0.13908549019607844, 0.13908549019607844,
#         ..., 0.18557098039215686, 0.18557098039215686,
#         0.18557098039215686],
#        [0.49117999999999995, 0.49117999999999995, 0.49117999999999995,
#         ..., 0.6892505857369762, 0.7011685299837906, 0.7156773959730636],
#        [0.15914272193080808, 0.11573804280615668, 0.08021724120365797,
#         ..., 0.12175085218172235, 0.14653428189503245,
#         0.1457746411021565],
#        ...,
#        [0.2873562951138491, 0.28801286952369304, 0.2881028108177468, ...,
#         0.5814297085204146, 0.5811667596667088, 0.5811727616274202],
#        [0.8191027450980392, 0.819102745098039, 0.819102745098039, ...,
#         0.05363725490196079, 0.053637254901960786, 0.053637254901960786],
#        [0.09536328083711512, 0.09050605822394878, 0.0965942208144244,
#         ..., 0.15237568627450984, 0.15237568627450984,
#         0.15237568627450984]], dtype=object)

# %%
y
# Out:
# array(['MADS', 'KEANU', 'DICAPRIO', 'KEANU', 'KEANU', 'DICAPRIO', 'KEANU',
#        'KEANU', 'DICAPRIO', 'KEANU', 'KEANU', 'DICAPRIO', 'KEANU',
#        'DICAPRIO', 'KEANU', 'KEANU', 'DICAPRIO', 'MADS', 'MADS', 'MADS',
#        'KEANU', 'DICAPRIO', 'DICAPRIO', 'DICAPRIO', 'DICAPRIO',
#        'DICAPRIO', 'MADS', 'KEANU', 'KEANU', 'DICAPRIO', 'KEANU', 'KEANU',
#        'KEANU', 'MADS', 'DICAPRIO', 'MADS', 'DICAPRIO', 'DICAPRIO',
#        'MADS', 'KEANU', 'DICAPRIO', 'KEANU', 'DICAPRIO', 'DICAPRIO',
#        'DICAPRIO', 'KEANU', 'DICAPRIO', 'KEANU', 'MADS', 'MADS'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()

# %%
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['KEANU', 'DICAPRIO', 'KEANU', 'KEANU', 'DICAPRIO', 'KEANU',
#        'DICAPRIO', 'KEANU', 'DICAPRIO', 'KEANU'], dtype=object)

# %%
for i in (np.random.randint(0,4,6)):
    predicted_images=(np.reshape(x_test[i],(512,512)).astype(np.float64))
    plt.title('predicted label:{0}'.format(y_pred[i]))
    plt.imshow(predicted_images,interpolation='nearest',cmap='gray')
    plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[3, 0, 0],
#        [0, 6, 0],
#        [1, 0, 0]], dtype=int64)
